# %% [markdown]
# # About this notebook.
# This is an implementation of darknet yolov3 by AlexeyAB (which is forked version of darknet from the official pjreddie darknet) in google colab.
#
# The AlexeyAB version is used to detect objects in a video file and save it in another video file which was not possible in the original version by pjreddie easily.
#
# The input video I have taken from youtube, uploading it is also possible.
# The result video file can be saved in your google drive or can be downloaded directly.
#
# # Steps :-

# %% [markdown]
# # 1. Getting necessary files.

# %%
#Cloning AlexeyAB darknet which is a forked version of darknet with extra features.
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 10884 (delta 0), reused 0 (delta 0), pack-reused 10881
# Receiving objects: 100% (10884/10884), 10.36 MiB | 18.92 MiB/s, done.
# Resolving deltas: 100% (7373/7373), done.

# %%
#Changing directory to darknet
# %cd darknet
# Out:
# /content/darknet

# %%
# %ls
# Out:
# darknet/  drive/  sample_data/

# %%
#Downloading yolov3 weights file from official website of darknet
# !wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2019-09-22 17:16:28--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  68.0MB/s    in 3.7s
#
# 2019-09-22 17:16:32 (64.0 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
#Downloading yolov3-tiny weights file from official website of darknet
# !wget https://pjreddie.com/media/files/yolov3-tiny.weights
# Out:
# --2019-09-22 17:17:03--  https://pjreddie.com/media/files/yolov3-tiny.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35434956 (34M) [application/octet-stream]
# Saving to: ‘yolov3-tiny.weights’
#
# yolov3-tiny.weights 100%[===================>]  33.79M  48.4MB/s    in 0.7s
#
# 2019-09-22 17:17:03 (48.4 MB/s) - ‘yolov3-tiny.weights’ saved [35434956/35434956]

# %%
#Not required as opencv already installed in colab (colab)
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.6/dist-packages (3.4.5.20)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from opencv-python) (1.16.5)

# %% [markdown]
# # 2. Making darknet.

# %%
#Edit the makefile to enable gpu and opencv
# !sed -i 's/GPU=0/GPU=1/g' Makefile
# !sed -i 's/OPENCV=0/OPENCV=1/g' Makefile

# %%
#Make darknet
# !make

# %% [markdown]
# # 3. Running yolo with darknet.

# %% [markdown]
# ## ----Image Detection----

# %%
#Image detection on dog.jpg and save predictions in predictions.jpg
# !./darknet detect cfg/yolov3.cfg yolov3.weights data/dog.jpg

# %%
# %ls #List files to check (optional)

# %%
#Download predictions.jpg if you want to. (Optional)
from google.colab import files
files.download('predictions.jpg')

# %% [markdown]
# ## ----Video Detection----

# %%
#Install pytube to download videos from youtube
# !pip install pytube
# Out:
# Collecting pytube
#   Downloading https://files.pythonhosted.org/packages/1b/ba/9ef6d885d48e7a4305772471f41dc74cae080487e99aa617f27ec9e4f3d7/pytube-9.5.2-py3-none-any.whl
# Installing collected packages: pytube
# Successfully installed pytube-9.5.2

# %%
#Download youtube video
from pytube import YouTube
YouTube('https://www.youtube.com/watch?v=7Y59oGt2XWU&t=4s').streams.filter(subtype="mp4",res="720p").first().download()
# Out:
# '/content/darknet/Baby Driver Running Scene (1080p).mp4'

# %%
#Rename downloaded video
# !mv 'Baby Driver Running Scene (1080p).mp4' 'video.mp4'

# %%
#Video detection on video.mp4 and store result in res.mp4
# !./darknet detector demo cfg/coco.data cfg/yolov3.cfg yolov3.weights 'video.mp4' -out_filename 'res.mp4' -dont_show
# Out:
# Demo
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5
#    9 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#   10 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8
#   12 conv    256       3 x 3/ 2    104 x 104 x 128 ->   52 x  52 x 256 1.595 BF
#   13 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   14 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   15 Shortcut Layer: 12
#   16 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   17 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   18 Shortcut Layer: 15
#   19 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   20 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   21 Shortcut Layer: 18
#   22 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   23 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   24 Shortcut Layer: 21
#   25 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   26 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   27 Shortcut Layer: 24
#   28 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   29 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   30 Shortcut Layer: 27
#   31 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   32 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   33 Shortcut Layer: 30
#   34 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   35 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   36 Shortcut Layer: 33
#   37 conv    512       3 x 3/ 2     52 x  52 x 256 ->   26 x  26 x 512 1.595 BF
#   38 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   39 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   40 Shortcut Layer: 37
#   41 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   42 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   43 Shortcut Layer: 40
#   44 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   45 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   46 Shortcut Layer: 43
#   47 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   48 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   49 Shortcut Layer: 46
#   50 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   51 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   52 Shortcut Layer: 49
#   53 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   54 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   55 Shortcut Layer: 52
#   56 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   57 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   58 Shortcut Layer: 55
#   59 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   60 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   61 Shortcut Layer: 58
#   62 conv   1024       3 x 3/ 2     26 x  26 x 512 ->   13 x  13 x1024 1.595 BF
#   63 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   64 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   65 Shortcut Layer: 62
#   66 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   67 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   68 Shortcut Layer: 65
#   69 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   70 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   71 Shortcut Layer: 68
#   72 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   73 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   74 Shortcut Layer: 71
#   75 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   76 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   77 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   78 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   79 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   80 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   81 conv    255       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 255 0.088 BF
#   82 yolo
# [yolo] params: iou loss: mse, iou_norm: 0.75, cls_norm: 1.00, scale_x_y: 1.00
#   83 route  79
#   84 conv    256       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 256 0.044 BF
#   85 upsample                 2x    13 x  13 x 256 ->   26 x  26 x 256
#   86 route  85 61
#   87 conv    256       1 x 1/ 1     26 x  26 x 768 ->   26 x  26 x 256 0.266 BF
#   88 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   89 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   90 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   91 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   92 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   93 conv    255       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 255 0.177 BF
#   94 yolo
# [yolo] params: iou loss: mse, iou_norm: 0.75, cls_norm: 1.00, scale_x_y: 1.00
#   95 route  91
#   96 conv    128       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 128 0.044 BF
#   97 upsample                 2x    26 x  26 x 128 ->   52 x  52 x 128
#   98 route  97 36
#   99 conv    128       1 x 1/ 1     52 x  52 x 384 ->   52 x  52 x 128 0.266 BF
#  100 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  101 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#  102 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  103 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#  104 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  105 conv    255       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 255 0.353 BF
#  106 yolo
# [yolo] params: iou loss: mse, iou_norm: 0.75, cls_norm: 1.00, scale_x_y: 1.00
# Total BFLOPS 65.864
#  Allocate additional workspace_size = 49.84 MB
# Loading weights from yolov3.weights...
#  seen 64
# Done! Loaded 107 layers from weights-file
# video file: video.mp4
# Video stream: 1280 x 534
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 13 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# Objects:
#
#
# FPS:0.0
# Objects:
#
# person: 100%
#
# FPS:-0.0
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:13.7
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:12.7
#
#  cvWriteFrame
# Objects:
#
# person: 98%
#
# FPS:13.0
#
#  cvWriteFrame
# Objects:
#
# person: 59%
#
# FPS:12.9
#
#  cvWriteFrame
# Objects:
#
# handbag: 44%
# handbag: 36%
# stop sign: 65%
# truck: 92%
# bus: 33%
# car: 98%
# car: 70%
# car: 66%
# car: 31%
# person: 100%
# person: 100%
# person: 98%
#
# FPS:14.3
#
#  cvWriteFrame
# Objects:
#
# cell phone: 36%
# handbag: 54%
# handbag: 39%
# handbag: 30%
# stop sign: 62%
# truck: 96%
# car: 91%
# car: 69%
# car: 39%
# person: 99%
# person: 99%
# person: 97%
#
# FPS:15.2
#
#  cvWriteFrame
# Objects:
#
# handbag: 74%
# handbag: 53%
# handbag: 52%
# stop sign: 58%
# truck: 86%
# bus: 45%
# car: 93%
# car: 83%
# car: 50%
# car: 29%
# person: 99%
# person: 99%
# person: 98%
# person: 27%
#
# FPS:14.9
#
#  cvWriteFrame
# Objects:
#
# handbag: 57%
# handbag: 46%
# handbag: 37%
# stop sign: 48%
# truck: 89%
# bus: 39%
# car: 73%
# car: 52%
# car: 33%
# person: 99%
# person: 99%
# person: 98%
#
# FPS:15.4
#
#  cvWriteFrame
# Objects:
#
# handbag: 72%
# handbag: 67%
# handbag: 28%
# truck: 89%
# bus: 40%
# car: 77%
# car: 58%
# car: 50%
# person: 33% car: 42%
# person: 99%
# person: 99%
# person: 98%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# handbag: 78%
# handbag: 48%
# stop sign: 29%
# truck: 91%
# bus: 36%
# car: 91%
# car: 54%
# car: 33%
# person: 99%
# person: 98%
# person: 98%
#
# FPS:15.3
#
#  cvWriteFrame
# Objects:
#
# handbag: 47%
# handbag: 47%
# truck: 93%
# bus: 45%
# car: 84%
# car: 51%
# person: 99%
# person: 98%
# person: 83%
#
# FPS:15.9
#
#  cvWriteFrame
# Objects:
#
# handbag: 37%
# handbag: 32%
# truck: 81%
# bus: 76%
# car: 97%
# car: 53%
# car: 45%
# person: 100%
# person: 99%
# person: 98%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# truck: 91%
# bus: 47%
# car: 83%
# car: 27%
# person: 98%
# person: 97%
# person: 77%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# tie: 36%
# truck: 96%
# car: 66% truck: 28%
# car: 42%
# person: 98%
# person: 95%
#
# FPS:16.7
#
#  cvWriteFrame
# Objects:
#
# handbag: 37%
# stop sign: 26%
# truck: 92%
# bus: 29%
# truck: 26%
# car: 78%
# car: 40%
# car: 30%
# person: 99%
# person: 98%
# person: 71%
#
# FPS:15.9
#
#  cvWriteFrame
# Objects:
#
# handbag: 43%
# stop sign: 28%
# truck: 95%
# car: 73%
# car: 43%
# car: 32%
# person: 99%
# person: 99%
# person: 90%
#
# FPS:15.9
#
#  cvWriteFrame
# Objects:
#
# handbag: 61%
# handbag: 27%
# stop sign: 44%
# truck: 97%
# car: 90%
# car: 54%
# car: 44%
# car: 35%
# person: 100%
# person: 98%
# person: 84%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# handbag: 49%
# stop sign: 31%
# truck: 98%
# car: 85%
# car: 53%
# car: 40%
# person: 100%
# person: 98%
# person: 96%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# stop sign: 35%
# truck: 97%
# car: 92%
# car: 66%
# car: 30%
# person: 100%
# person: 100%
# person: 84%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# cell phone: 30%
# stop sign: 53%
# truck: 96%
# car: 95%
# car: 72%
# car: 70%
# person: 100%
# person: 100%
# person: 78%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# stop sign: 42%
# truck: 98%
# car: 94%
# car: 69%
# car: 46%
# car: 40%
# person: 100%
# person: 99%
# person: 90%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# handbag: 29%
# truck: 96%
# car: 93%
# car: 60%
# car: 47%
# person: 49% car: 46%
# person: 100%
# person: 99%
# person: 75%
#
# FPS:15.5
#
#  cvWriteFrame
# Objects:
#
# handbag: 56%
# truck: 99%
# car: 72%
# car: 68%
# person: 72% car: 26%
# person: 99%
# person: 99%
# person: 83%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# truck: 97%
# car: 90%
# car: 62%
# car: 44%
# person: 25%
# car: 30%
# person: 100%
# person: 96%
# person: 86%
#
# FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# stop sign: 33%
# truck: 98%
# truck: 32%
# car: 91%
# car: 72%
# car: 64%
# person: 100%
# person: 97%
# person: 94%
#
# FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# handbag: 57%
# stop sign: 31%
# truck: 98%
# truck: 58%
# car: 76%
# car: 54%
# car: 41%
# person: 100%
# person: 97%
# person: 78%
#
# FPS:16.1
#
#  cvWriteFrame
# Objects:
#
# handbag: 27%
# truck: 99%
# car: 66% truck: 54%
# car: 71%
# person: 25% car: 35%
# person: 100%
# person: 99%
# person: 48%
# person: 31%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# stop sign: 30%
# truck: 99%
# car: 76% truck: 37%
# person: 30% car: 61%
# car: 51%
# person: 99%
# person: 93%
# person: 49%
# person: 41%
#
# FPS:16.1
#
#  cvWriteFrame
# Objects:
#
# handbag: 36%
# stop sign: 35%
# truck: 99%
# car: 93%
# person: 56% car: 56%
# car: 42%
# car: 30%
# person: 97%
# person: 97%
# person: 77%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# stop sign: 30%
# truck: 100%
# car: 81%
# car: 49%
# car: 46%
# car: 34%
# person: 26% car: 34%
# person: 100%
# person: 95%
# person: 71%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# stop sign: 30%
# truck: 100%
# car: 88%
# car: 57%
# person: 28% car: 49%
# car: 28%
# person: 97%
# person: 95%
# person: 32%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# stop sign: 52%
# truck: 100%
# truck: 26%
# car: 93%
# car: 56%
# car: 47%
# person: 98%
# person: 82%
#
# FPS:16.6
#
#  cvWriteFrame
# Objects:
#
# stop sign: 35%
# truck: 100%
# car: 94%
# car: 43%
# person: 99%
# person: 56%
#
# FPS:18.3
#
#  cvWriteFrame
# Objects:
#
# stop sign: 28%
# truck: 100%
# truck: 29%
# car: 95%
# car: 32%
# person: 99%
# person: 61%
#
# FPS:15.1
#
#  cvWriteFrame
# Objects:
#
# stop sign: 41%
# truck: 100%
# car: 95%
# car: 37%
# car: 30%
# person: 100%
# person: 77%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# stop sign: 49%
# truck: 100%
# car: 94%
# car: 50%
# person: 27%
# person: 100%
# person: 63%
# person: 43%
#
# FPS:15.2
#
#  cvWriteFrame
# Objects:
#
# stop sign: 47%
# truck: 100%
# car: 92%
# car: 85%
# person: 100%
# person: 61%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# backpack: 36%
# truck: 100%
# car: 76%
# car: 29%
# person: 99%
# person: 62%
# person: 26%
#
# FPS:15.8
#
#  cvWriteFrame
# Objects:
#
# truck: 100%
# car: 86%
# car: 51%
# person: 99%
# person: 41%
#
# FPS:15.8
#
#  cvWriteFrame
# Objects:
#
# truck: 100%
# car: 86%
# person: 43% car: 35%
# car: 30%
# person: 99%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# truck: 100%
# car: 72%
# person: 62% car: 47%
# car: 32%
# person: 98%
# person: 41%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# backpack: 38% suitcase: 28%
# handbag: 26%
# truck: 100%
# person: 59% car: 71%
# car: 65%
# car: 40%
# person: 99%
# person: 64%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# handbag: 29%
# backpack: 43%
# truck: 100%
# car: 53%
# person: 28% car: 52%
# car: 46%
# person: 98%
# person: 38%
#
# FPS:16.8
#
#  cvWriteFrame
# Objects:
#
# backpack: 34%
# truck: 100%
# person: 47% car: 45%
# car: 28%
# car: 26%
# person: 100%
#
# FPS:16.6
#
#  cvWriteFrame
# Objects:
#
# backpack: 49%
# truck: 99%
# car: 60%
# car: 39%
# car: 29%
# person: 99%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# truck: 98%
# car: 53%
# car: 41%
# car: 40%
# car: 34%
# person: 99%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# truck: 98%
# car: 39%
# car: 36%
# person: 100%
# person: 71%
#
# FPS:15.4
#
#  cvWriteFrame
# Objects:
#
# backpack: 30%
# truck: 99%
# bus: 35%
# car: 46%
# person: 99%
# person: 38%
# person: 34%
#
# FPS:15.3
#
#  cvWriteFrame
# Objects:
#
# truck: 90%
# bus: 43%
# car: 64%
# car: 33%
# car: 29%
# person: 100%
# person: 29%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# bus: 46% truck: 65%
# train: 65%
# train: 60%
# car: 66%
# car: 38%
# car: 36%
# person: 99%
# person: 33%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# truck: 53%
# train: 42%
# car: 63%
# car: 25%
# person: 99%
# person: 83%
# person: 28%
#
# FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# car: 62%
# car: 35%
# person: 100%
# person: 61%
#
# FPS:16.6
#
#  cvWriteFrame
# Objects:
#
# suitcase: 25%
# backpack: 31%
# car: 72%
# car: 28%
# person: 99%
# person: 61%
# person: 56%
#
# FPS:16.8
#
#  cvWriteFrame
# Objects:
#
# backpack: 60% suitcase: 49%
# backpack: 37%
# car: 82%
# person: 100%
# person: 97%
# person: 48%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# backpack: 54% suitcase: 49%
# suitcase: 32%
# backpack: 38%
# car: 54%
# car: 38%
# person: 99%
# person: 91%
#
# FPS:15.2
#
#  cvWriteFrame
# Objects:
#
# cell phone: 29%
# backpack: 48% suitcase: 37%
# backpack: 57%
# car: 29%
# person: 99%
# person: 43%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# backpack: 37% handbag: 34%
# backpack: 37%
# car: 32%
# person: 99%
# person: 32%
# person: 26%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# handbag: 27%
# backpack: 56%
# backpack: 47%
# bus: 39%
# car: 37%
# car: 29%
# person: 99%
# person: 32%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# bus: 26%
# car: 33%
# person: 100%
# person: 79%
# person: 34%
#
# FPS:15.3
#
#  cvWriteFrame
# Objects:
#
# backpack: 40%
# bus: 86%
# person: 100%
# person: 83%
# person: 42%
#
# FPS:16.7
#
#  cvWriteFrame
# Objects:
#
# backpack: 39%
# bus: 89%
# car: 34%
# person: 99%
# person: 90%
# person: 49%
#
# FPS:16.8
#
#  cvWriteFrame
# Objects:
#
# person: 98%
# person: 97%
# person: 93%
# person: 68%
#
# FPS:16.6
#
#  cvWriteFrame
# Objects:
#
# backpack: 50%
# parking meter: 53%
# person: 99%
# person: 98%
# person: 73%
#
# FPS:15.8
#
#  cvWriteFrame
# Objects:
#
# backpack: 43%
# person: 98%
# person: 97%
# person: 75%
#
# FPS:15.8
#
#  cvWriteFrame
# Objects:
#
# backpack: 61%
# car: 34%
# person: 100%
# person: 97%
# person: 83%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# car: 39%
# person: 98%
# person: 91%
# person: 88%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# backpack: 62%
# car: 43%
# person: 99%
# person: 87%
# person: 81%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# backpack: 46%
# person: 99%
# person: 96%
# person: 92%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# backpack: 31%
# person: 99%
# person: 92%
# person: 62%
# person: 29%
#
# FPS:16.1
#
#  cvWriteFrame
# Objects:
#
# backpack: 29%
# car: 25%
# person: 99%
# person: 91%
# person: 90%
# person: 29%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# car: 39%
# person: 98%
# person: 97%
# person: 51%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# backpack: 37%
# car: 29%
# person: 100%
# person: 89%
# person: 61%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# person: 98%
# person: 90%
# person: 30%
# person: 27%
#
# FPS:16.6
#
#  cvWriteFrame
# Objects:
#
# person: 98%
# person: 79%
# person: 51%
# person: 31%
#
# FPS:15.9
#
#  cvWriteFrame
# Objects:
#
# person: 100%
# person: 90%
#
# FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# car: 31%
# person: 100%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:15.2
#
#  cvWriteFrame
# Objects:
#
# backpack: 37%
# person: 100%
# person: 49%
# person: 34%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# backpack: 42%
# person: 99%
# person: 33%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# backpack: 43%
# backpack: 36%
# person: 88%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# backpack: 34%
# person: 98%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# person: 96%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 84%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 88%
#
# FPS:15.9
#
#  cvWriteFrame
# Objects:
#
# backpack: 46%
# person: 98%
#
# FPS:15.2
#
#  cvWriteFrame
# Objects:
#
# person: 84%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 97%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# person: 96%
#
# FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:16.1
#
#  cvWriteFrame
# Objects:
#
# person: 71%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# person: 38%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# person: 29%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# person: 52%
# person: 45%
# person: 25%
#
# FPS:15.8
#
#  cvWriteFrame
# Objects:
#
# person: 88%
#
# FPS:15.5
#
#  cvWriteFrame
# Objects:
#
# person: 30%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# car: 99%
# person: 97%
#
# FPS:15.4
#
#  cvWriteFrame
# Objects:
#
# backpack: 36%
# car: 64%
# person: 100%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# backpack: 34%
# backpack: 28%
# car: 59%
# person: 98%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# car: 67%
# person: 96%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# car: 91%
# person: 98%
#
# FPS:15.1
#
#  cvWriteFrame
# Objects:
#
# car: 85%
# person: 97%
# person: 28%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# backpack: 33%
# car: 90%
# person: 99%
# person: 80%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# car: 90%
# car: 28%
# person: 100%
# person: 86%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# car: 100%
# person: 100%
# person: 95%
#
# FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# car: 99%
# person: 99%
# person: 90%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# handbag: 37%
# car: 99%
# person: 99%
# person: 96%
# person: 32%
#
# FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# truck: 40%
# car: 99%
# person: 99%
# person: 93%
# person: 36%
# person: 36%
# person: 33%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# car: 97%
# person: 99%
# person: 95%
# person: 43%
# person: 27%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# car: 68%
# person: 98%
# person: 84%
# person: 82%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# car: 76%
# person: 97%
# person: 96%
# person: 91%
#
# FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# car: 73%
# person: 99%
# person: 99%
# person: 90%
#
# FPS:18.1
#
#  cvWriteFrame
# Objects:
#
# car: 86%
# person: 100%
# person: 99%
# person: 70%
#
# FPS:15.3
#
#  cvWriteFrame
# Objects:
#
# handbag: 37%
# backpack: 50%
# car: 93%
# person: 100%
# person: 85%
#
# FPS:15.3
#
#  cvWriteFrame
# Objects:
#
# handbag: 30%
# car: 92%
# person: 99%
# person: 92%
#
# FPS:16.7
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 36%
# bus: 63%
# car: 96%
# person: 99%
# person: 99%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 43%
# backpack: 62%
# backpack: 30%
# car: 98%
# person: 99%
# person: 88%
#
# FPS:16.1
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 44%
# backpack: 46%
# car: 97%
# person: 99%
# person: 81%
# person: 29%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 48%
# car: 98%
# person: 99%
# person: 56%
# person: 50%
#
# FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# car: 98%
# person: 98%
# person: 97%
# person: 86%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# car: 98%
# person: 100%
# person: 99%
# person: 87%
#
# FPS:15.1
#
#  cvWriteFrame
# Objects:
#
# handbag: 35%
# car: 99%
# person: 100%
# person: 99%
# person: 96%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# handbag: 74%
# car: 98%
# person: 100%
# person: 99%
# person: 85%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# backpack: 32% handbag: 65%
# car: 94%
# person: 99%
# person: 99%
# person: 97%
#
# FPS:15.5
#
#  cvWriteFrame
# Objects:
#
# handbag: 60%
# car: 88%
# person: 99%
# person: 97%
# person: 96%
#
# FPS:15.1
#
#  cvWriteFrame
# Objects:
#
# handbag: 48%
# backpack: 31%
# car: 83%
# person: 100%
# person: 85%
# person: 85%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# handbag: 70%
# handbag: 33%
# handbag: 32%
# car: 94%
# person: 100%
# person: 90%
# person: 73%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# backpack: 28% handbag: 60%
# car: 82%
# person: 98%
# person: 96%
# person: 93%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# backpack: 28% handbag: 49%
# backpack: 30%
# dog: 38%
# car: 84%
# person: 100%
# person: 79%
# person: 51%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# handbag: 50%
# backpack: 36%
# car: 97%
# person: 100%
# person: 94%
# person: 91%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# handbag: 41%
# handbag: 37%
# backpack: 45%
# car: 98%
# person: 100%
# person: 98%
# person: 87%
#
# FPS:15.4
#
#  cvWriteFrame
# Objects:
#
# handbag: 32%
# car: 92%
# person: 100%
# person: 97%
# person: 89%
#
# FPS:15.8
#
#  cvWriteFrame
# Objects:
#
# car: 96%
# person: 100%
# person: 91%
# person: 39%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# car: 97%
# person: 100%
# person: 97%
# person: 83%
#
# FPS:15.1
#
#  cvWriteFrame
# Objects:
#
# car: 92%
# person: 100%
# person: 99%
# person: 74%
#
# FPS:18.3
#
#  cvWriteFrame
# Objects:
#
# car: 94%
# person: 100%
# person: 99%
# person: 95%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# handbag: 27%
# car: 89%
# person: 99%
# person: 99%
# person: 93%
# person: 49%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# handbag: 31%
# car: 56%
# person: 100%
# person: 98%
# person: 79%
# person: 51%
#
# FPS:14.7
#
#  cvWriteFrame
# Objects:
#
# truck: 28%
# car: 79%
# person: 100%
# person: 90%
# person: 57%
#
# FPS:15.8
#
#  cvWriteFrame
# Objects:
#
# truck: 35%
# car: 52%
# bicycle: 42%
# person: 100%
# person: 83%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 27%
# car: 65%
# bicycle: 36%
# person: 100%
# person: 97%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# person: 100%
# person: 96%
#
# FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# truck: 29%
# person: 100%
# person: 99%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# person: 100%
# person: 99%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# car: 60%
# person: 100%
# person: 97%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# car: 45%
# person: 100%
# person: 91%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# person: 41%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# baseball bat: 33%
# person: 48%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# person: 88%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 86%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 89%
#
# FPS:16.1
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 96%
#
# FPS:15.3
#
#  cvWriteFrame
# Objects:
#
# person: 84%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# person: 91%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# person: 94%
#
# FPS:16.1
#
#  cvWriteFrame
# Objects:
#
# person: 85%
#
# FPS:15.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.9
#
#  cvWriteFrame
# Objects:
#
# person: 40%
#
# FPS:14.8
#
#  cvWriteFrame
# Objects:
#
# person: 34%
#
# FPS:14.8
#
#  cvWriteFrame
# Objects:
#
# backpack: 38%
# person: 97%
# person: 96%
#
# FPS:16.8
#
#  cvWriteFrame
# Objects:
#
# person: 93%
# person: 92%
#
# FPS:15.5
#
#  cvWriteFrame
# Objects:
#
# person: 92%
# person: 68%
#
# FPS:16.6
#
#  cvWriteFrame
# Objects:
#
# person: 98%
# person: 97%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# backpack: 32%
# person: 98%
# person: 98%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 96%
# person: 31%
#
# FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# person: 90%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 99%
# person: 85%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# person: 100%
# person: 86%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# person: 100%
# person: 69%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# person: 98%
#
# FPS:16.6
#
#  cvWriteFrame
# Objects:
#
# person: 98%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# person: 90%
# person: 32%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# cell phone: 34%
# person: 99%
# person: 85%
# person: 52%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.1
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# tie: 43%
# person: 99%
# person: 98%
# person: 67%
# person: 27%
#
# FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# person: 90%
# person: 86%
# person: 62%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# person: 84%
# person: 82%
# person: 51%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# handbag: 26%
# backpack: 29%
# person: 98%
# person: 96%
#
# FPS:15.2
#
#  cvWriteFrame
# Objects:
#
# handbag: 45%
# backpack: 28%
# person: 99%
# person: 79%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# person: 98%
# person: 87%
# person: 64%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# person: 87%
# person: 70%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# person: 95%
# person: 90%
#
# FPS:16.6
#
#  cvWriteFrame
# Objects:
#
# person: 98%
# person: 96%
# person: 30%
#
# FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# person: 95%
# person: 94%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# handbag: 29%
# backpack: 46%
# person: 96%
# person: 88%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# person: 93%
# person: 92%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# handbag: 27%
# person: 91%
# person: 89%
#
# FPS:16.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.2
#
#  cvWriteFrame
# Objects:
#
# person: 44%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# person: 74%
# person: 61%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 65%
#
# FPS:16.1
#
#  cvWriteFrame
# Objects:
#
# person: 40%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.1
#
#  cvWriteFrame
# Objects:
#
# person: 41%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.2
#
#  cvWriteFrame
# Objects:
#
# person: 38%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# person: 99%
# person: 97%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# person: 99%
# person: 96%
#
# FPS:16.1
#
#  cvWriteFrame
# Objects:
#
# sports ball: 27%
# person: 100%
# person: 97%
#
# FPS:16.1
#
#  cvWriteFrame
# Objects:
#
# person: 100%
# person: 99%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# bottle: 35%
# person: 99%
# person: 99%
#
# FPS:15.1
#
#  cvWriteFrame
# Objects:
#
# person: 99%
# person: 99%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 99%
# person: 99%
#
# FPS:16.1
#
#  cvWriteFrame
# Objects:
#
# person: 100%
# person: 99%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 99%
# person: 99%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# person: 96%
# person: 96%
#
# FPS:16.1
#
#  cvWriteFrame
# Objects:
#
# person: 99%
# person: 97%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# person: 94%
# person: 90%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# person: 97%
# person: 95%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 99%
# person: 97%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# person: 100%
# person: 90%
#
# FPS:16.1
#
#  cvWriteFrame
# Objects:
#
# person: 81%
# person: 69%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# person: 98%
# person: 34%
#
# FPS:16.6
#
#  cvWriteFrame
# Objects:
#
# person: 96%
# person: 68%
#
# FPS:16.1
#
#  cvWriteFrame
# Objects:
#
# person: 91%
# person: 71%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# cell phone: 49%
# person: 73%
#
# FPS:16.6
#
#  cvWriteFrame
# Objects:
#
# person: 81%
# person: 27%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# person: 99%
# person: 50%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# person: 98%
# person: 52%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# person: 100%
# person: 84%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 94%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 89%
#
# FPS:17.8
#
#  cvWriteFrame
# Objects:
#
# person: 76%
# person: 68%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# person: 86%
# person: 52%
#
# FPS:15.9
#
#  cvWriteFrame
# Objects:
#
# person: 62%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.0
#
#  cvWriteFrame
# Objects:
#
# person: 77%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# person: 58%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# person: 98%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:15.9
#
#  cvWriteFrame
# Objects:
#
# backpack: 30%
# person: 97%
# person: 72%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 99%
# person: 46%
#
# FPS:16.1
#
#  cvWriteFrame
# Objects:
#
# person: 99%
# person: 39%
#
# FPS:16.1
#
#  cvWriteFrame
# Objects:
#
# person: 99%
# person: 97%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 26%
# person: 100%
# person: 96%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# handbag: 32%
# person: 100%
# person: 89%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 99%
# person: 99%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# person: 99%
# person: 99%
#
# FPS:14.9
#
#  cvWriteFrame
# Objects:
#
# person: 100%
# person: 99%
#
# FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# person: 100%
# person: 99%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 99%
# person: 94%
#
# FPS:15.9
#
#  cvWriteFrame
# Objects:
#
# person: 100%
# person: 98%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# backpack: 38%
# person: 100%
# person: 95%
#
# FPS:15.2
#
#  cvWriteFrame
# Objects:
#
# backpack: 72%
# backpack: 63%
# person: 98%
# person: 98%
#
# FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# person: 99%
# person: 93%
#
# FPS:16.8
#
#  cvWriteFrame
# Objects:
#
# person: 100%
# person: 96%
#
# FPS:15.9
#
#  cvWriteFrame
# Objects:
#
# person: 100%
# person: 98%
#
# FPS:15.5
#
#  cvWriteFrame
# Objects:
#
# backpack: 34%
# person: 100%
# person: 91%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# person: 99%
# person: 97%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# person: 100%
# person: 99%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# person: 99%
# person: 98%
#
# FPS:16.6
#
#  cvWriteFrame
# Objects:
#
# person: 99%
# person: 94%
# person: 27%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# person: 98%
# person: 97%
# person: 95%
# person: 94%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 98%
# person: 98%
# person: 95%
# person: 79%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 64%
# person: 99%
# person: 98%
# person: 50%
# person: 45%
# person: 42%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# person: 99%
# person: 96%
# person: 79%
# person: 51%
#
# FPS:14.9
#
#  cvWriteFrame
# Objects:
#
# person: 99%
# person: 91%
# person: 84%
# person: 84%
# person: 36%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# person: 99%
# person: 87%
# person: 81%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 97%
# person: 89%
# person: 70%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# person: 97%
# person: 80%
# person: 77%
# person: 32%
#
# FPS:15.3
#
#  cvWriteFrame
# Objects:
#
# person: 99%
# person: 94%
# person: 87%
# person: 28%
#
# FPS:16.1
#
#  cvWriteFrame
# Objects:
#
# person: 100%
# person: 34%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# person: 98%
# person: 80%
#
# FPS:16.1
#
#  cvWriteFrame
# Objects:
#
# person: 90%
# person: 25%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 98%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# person: 87%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 70%
# person: 69%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# person: 96%
#
# FPS:14.3
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:15.3
#
#  cvWriteFrame
# Objects:
#
# person: 96%
#
# FPS:17.5
#
#  cvWriteFrame
# Objects:
#
# person: 27%
#
# FPS:16.7
#
#  cvWriteFrame
# Objects:
#
# person: 97%
#
# FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# person: 97%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# person: 25%
#
# FPS:15.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# chair: 39%
# cup: 42%
#
# FPS:16.6
#
#  cvWriteFrame
# Objects:
#
# person: 47%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# person: 98%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 67%
#
# FPS:15.8
#
#  cvWriteFrame
# Objects:
#
# chair: 44%
# person: 73%
# person: 63%
#
# FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# person: 94%
# person: 65%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# person: 77%
# person: 59%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# chair: 34%
# chair: 28%
# chair: 26%
# person: 98%
# person: 60%
#
# FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# person: 96%
# person: 49%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# person: 100%
# person: 89%
#
# FPS:15.5
#
#  cvWriteFrame
# Objects:
#
# person: 98%
# person: 48%
#
# FPS:14.9
#
#  cvWriteFrame
# Objects:
#
# person: 100%
# person: 46%
#
# FPS:15.9
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# person: 97%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# person: 97%
#
# FPS:15.5
#
#  cvWriteFrame
# Objects:
#
# person: 79%
#
# FPS:15.2
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 30%
# person: 98%
# person: 49%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:15.5
#
#  cvWriteFrame
# Objects:
#
# person: 57%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 60%
# person: 30%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# person: 27%
#
# FPS:15.4
#
#  cvWriteFrame
# Objects:
#
# person: 89%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 100%
# person: 51%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:15.1
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# person: 96%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# person: 91%
#
# FPS:15.3
#
#  cvWriteFrame
# Objects:
#
# cup: 57%
# person: 35%
# person: 30%
#
# FPS:17.5
#
#  cvWriteFrame
# Objects:
#
# person: 43%
# person: 34%
#
# FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# person: 87%
#
# FPS:15.1
#
#  cvWriteFrame
# Objects:
#
# vase: 48%
# pottedplant: 52%
# pottedplant: 29%
# person: 96%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 33%
# person: 95%
# person: 31%
#
# FPS:15.3
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 45%
# person: 98%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# chair: 27%
# person: 100%
#
# FPS:16.6
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 27%
# person: 99%
#
# FPS:15.4
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 43%
# person: 93%
#
# FPS:14.3
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 35%
# chair: 43%
# chair: 28%
# person: 99%
#
# FPS:15.3
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 51%
# person: 100%
#
# FPS:16.7
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 42%
# bench: 54%
# person: 100%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 89%
# person: 35% pottedplant: 26%
# bicycle: 26%
# person: 99%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 46%
# person: 100%
#
# FPS:13.4
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:16.6
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 26%
# person: 99%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# person: 100%
# person: 33%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# person: 98%
# person: 27%
#
# FPS:15.1
#
#  cvWriteFrame
# Objects:
#
# elephant: 33%
# person: 90%
#
# FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# dog: 45%
# person: 65%
#
# FPS:15.1
#
#  cvWriteFrame
# Objects:
#
# person: 57%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:15.1
#
#  cvWriteFrame
# Objects:
#
# dog: 61%
# person: 97%
#
# FPS:14.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 96%
#
# FPS:14.9
#
#  cvWriteFrame
# Objects:
#
# dog: 29%
# person: 82%
#
# FPS:15.3
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:15.3
#
#  cvWriteFrame
# Objects:
#
# person: 67%
#
# FPS:15.3
#
#  cvWriteFrame
# Objects:
#
# person: 77%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# elephant: 70%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 96%
#
# FPS:15.4
#
#  cvWriteFrame
# Objects:
#
# person: 93%
# person: 62%
# person: 42%
#
# FPS:15.5
#
#  cvWriteFrame
# Objects:
#
# person: 84%
#
# FPS:15.4
#
#  cvWriteFrame
# Objects:
#
# person: 96%
#
# FPS:16.6
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# person: 95%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# person: 80%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 95%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# bench: 75%
# person: 97%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# bench: 26%
# person: 97%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:14.2
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:15.9
#
#  cvWriteFrame
# Objects:
#
# bench: 47%
# person: 99%
#
# FPS:15.5
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# person: 92%
#
# FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# person: 93%
#
# FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# person: 98%
#
# FPS:16.1
#
#  cvWriteFrame
# Objects:
#
# person: 100%
# person: 33%
#
# FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# person: 95%
# person: 25%
#
# FPS:16.1
#
#  cvWriteFrame
# Objects:
#
# person: 94%
# person: 27%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:14.6
#
#  cvWriteFrame
# Objects:
#
# person: 98%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# person: 39%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.2
#
#  cvWriteFrame
# Objects:
#
# person: 29%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.1
#
#  cvWriteFrame
# Objects:
#
# person: 46%
#
# FPS:15.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:14.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# person: 36%
#
# FPS:15.4
#
#  cvWriteFrame
# Objects:
#
# person: 56%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# person: 83%
#
# FPS:15.1
#
#  cvWriteFrame
# Objects:
#
# person: 58%
#
# FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# person: 58%
#
# FPS:15.9
#
#  cvWriteFrame
# Objects:
#
# traffic light: 26%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# skateboard: 33% surfboard: 68%
# person: 99%
#
# FPS:15.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# person: 95%
# person: 73%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 85%
#
# FPS:15.1
#
#  cvWriteFrame
# Objects:
#
# person: 89%
# person: 81%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# person: 96%
#
# FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# person: 99%
# person: 72%
# person: 27%
#
# FPS:15.4
#
#  cvWriteFrame
# Objects:
#
# person: 100%
# person: 93%
# person: 40%
#
# FPS:15.5
#
#  cvWriteFrame
# Objects:
#
# person: 96%
# person: 87%
# person: 78%
#
# FPS:15.4
#
#  cvWriteFrame
# Objects:
#
# handbag: 70%
# person: 97%
# person: 94%
#
# FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# tennis racket: 40%
# person: 95%
# person: 51%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# person: 94%
# person: 85%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# person: 85%
# person: 31%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 93%
# person: 61%
# person: 37%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# person: 87%
# person: 31%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# person: 87%
# person: 31%
#
# FPS:16.1
#
#  cvWriteFrame
# Objects:
#
# toothbrush: 45%
# person: 83%
# person: 39%
#
# FPS:18.2
#
#  cvWriteFrame
# Objects:
#
# toothbrush: 41%
# person: 76%
# person: 52%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# person: 86%
# person: 83%
#
# FPS:18.1
#
#  cvWriteFrame
# Objects:
#
# person: 86%
# person: 83%
#
# FPS:17.8
#
#  cvWriteFrame
# Objects:
#
# person: 99%
# person: 95%
#
# FPS:14.7
#
#  cvWriteFrame
# Objects:
#
# dog: 68%
# person: 84%
# person: 91%
#
# FPS:14.6
#
#  cvWriteFrame
# Objects:
#
# person: 95%
# person: 83%
#
# FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# bird: 71%
# person: 31%
# person: 97%
#
# FPS:14.9
#
#  cvWriteFrame
# Objects:
#
# person: 94%
# person: 51%
#
# FPS:14.6
#
#  cvWriteFrame
# Objects:
#
# person: 98%
# person: 68%
#
# FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# person: 97%
# person: 87%
#
# FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# person: 96%
# person: 74%
#
# FPS:14.8
#
#  cvWriteFrame
# Objects:
#
# person: 99%
# person: 85%
#
# FPS:15.1
#
#  cvWriteFrame
# Objects:
#
# person: 100%
# person: 96%
#
# FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# person: 99%
# person: 85%
#
# FPS:15.1
#
#  cvWriteFrame
# Objects:
#
# person: 99%
# person: 93%
#
# FPS:18.0
#
#  cvWriteFrame
# Objects:
#
# cell phone: 32%
# person: 100%
# person: 82%
#
# FPS:14.7
#
#  cvWriteFrame
# Objects:
#
# cell phone: 47%
# person: 100%
# person: 81%
#
# FPS:14.3
#
#  cvWriteFrame
# Objects:
#
# person: 87%
# person: 87%
#
# FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# cell phone: 68%
# person: 99%
# person: 98%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# cell phone: 68%
# baseball bat: 25%
# person: 99%
# person: 98%
#
# FPS:14.9
#
#  cvWriteFrame
# Objects:
#
# cell phone: 71%
# cell phone: 31%
# person: 99%
# person: 97%
#
# FPS:15.1
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 66%
# pottedplant: 26%
# backpack: 78%
# person: 96%
#
# FPS:16.6
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 75%
# pottedplant: 32%
# backpack: 44%
# person: 96%
# person: 78%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 83%
# pottedplant: 33%
# person: 92%
# person: 84%
# person: 46%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 87%
# person: 92%
# person: 91%
# person: 74%
#
# FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 92%
# pottedplant: 31%
# person: 95%
# person: 90%
# person: 69%
#
# FPS:14.8
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 93%
# person: 100%
# person: 91%
# person: 57%
#
# FPS:17.1
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 94%
# pottedplant: 40%
# person: 98%
# person: 98%
# person: 87%
#
# FPS:16.6
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 94%
# pottedplant: 40%
# person: 98%
# person: 98%
# person: 87%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 87%
# pottedplant: 40%
# person: 98%
# person: 76%
# person: 48%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 83%
# pottedplant: 34%
# person: 95%
# person: 70%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 77%
# person: 96%
# person: 28%
#
# FPS:16.6
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 42%
# handbag: 33%
# person: 100%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 58%
# person: 100%
#
# FPS:15.2
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:13.9
#
#  cvWriteFrame
# Objects:
#
# person: 98%
#
# FPS:15.1
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# backpack: 38%
# person: 100%
#
# FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:16.1
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# backpack: 35%
# person: 99%
#
# FPS:15.3
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:14.7
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 100%
# person: 71%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# backpack: 55%
# person: 99%
# person: 77%
#
# FPS:15.2
#
#  cvWriteFrame
# Objects:
#
# person: 100%
# person: 60%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# person: 98%
#
# FPS:14.6
#
#  cvWriteFrame
# Objects:
#
# person: 96%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 96%
#
# FPS:15.2
#
#  cvWriteFrame
# Objects:
#
# person: 98%
#
# FPS:15.5
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 97%
#
# FPS:14.9
#
#  cvWriteFrame
# Objects:
#
# person: 96%
#
# FPS:17.2
#
#  cvWriteFrame
# Objects:
#
# person: 48%
#
# FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# person: 90%
#
# FPS:14.6
#
#  cvWriteFrame
# Objects:
#
# person: 97%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 98%
#
# FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:14.7
#
#  cvWriteFrame
# Objects:
#
# person: 97%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# person: 96%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# person: 93%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# train: 30%
# person: 99%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# train: 60%
# person: 93%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# train: 80%
# person: 98%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# train: 85%
# person: 90%
#
# FPS:15.2
#
#  cvWriteFrame
# Objects:
#
# train: 83%
# person: 94%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# train: 58%
# person: 99%
#
# FPS:15.3
#
#  cvWriteFrame
# Objects:
#
# train: 29%
# person: 99%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:15.5
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# train: 41%
# person: 92%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# train: 36%
# person: 95%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# train: 48%
# person: 100%
#
# FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# train: 26%
# person: 100%
#
# FPS:15.4
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:15.3
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:15.4
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:18.2
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 36%
# person: 99%
# person: 97%
#
# FPS:14.9
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 79%
# person: 99%
# person: 94%
#
# FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 54%
# person: 99%
# person: 95%
#
# FPS:13.8
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 60%
# person: 100%
# person: 92%
#
# FPS:14.7
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 33%
# person: 99%
# person: 90%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 44%
# pottedplant: 38%
# person: 99%
# person: 94%
# person: 25%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 58%
# pottedplant: 29%
# person: 99%
# person: 95%
# person: 29%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 45%
# person: 98%
# person: 91%
# person: 29%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 42%
# person: 98%
# person: 91%
#
# FPS:18.3
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 52%
# person: 97%
# person: 93%
#
# FPS:17.7
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 59%
# person: 98%
# person: 92%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 32%
# person: 99%
# person: 95%
#
# FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 44%
# person: 97%
# person: 96%
#
# FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 49%
# pottedplant: 42%
# person: 99%
# person: 93%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 65%
# pottedplant: 44%
# person: 99%
# person: 98%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 45%
# pottedplant: 31%
# pottedplant: 26%
# person: 98%
# person: 98%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 42%
# person: 98%
# person: 94%
#
# FPS:15.8
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 57%
# person: 98%
# person: 97%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 37%
# person: 100%
# person: 97%
#
# FPS:15.9
#
#  cvWriteFrame
# Objects:
#
# pottedplant: 43%
# person: 99%
# person: 97%
# person: 27%
#
# FPS:16.7
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:15.3
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:15.1
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:15.8
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:15.9
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:15.4
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:15.5
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:15.1
#
#  cvWriteFrame
# Objects:
#
# cell phone: 31%
# person: 99%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# remote: 73%
# person: 100%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# remote: 77%
# person: 100%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# remote: 53%
# person: 100%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# remote: 36%
# person: 99%
#
# FPS:15.3
#
#  cvWriteFrame
# Objects:
#
# person: 93%
#
# FPS:16.1
#
#  cvWriteFrame
# Objects:
#
# person: 90%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 92%
#
# FPS:14.9
#
#  cvWriteFrame
# Objects:
#
# person: 74%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# person: 78%
#
# FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# person: 72%
#
# FPS:15.9
#
#  cvWriteFrame
# Objects:
#
# person: 82%
#
# FPS:16.6
#
#  cvWriteFrame
# Objects:
#
# person: 84%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# person: 78%
#
# FPS:15.9
#
#  cvWriteFrame
# Objects:
#
# person: 75%
#
# FPS:16.7
#
#  cvWriteFrame
# Objects:
#
# person: 39%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:14.9
#
#  cvWriteFrame
# Objects:
#
# person: 43%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# person: 54%
#
# FPS:15.4
#
#  cvWriteFrame
# Objects:
#
# traffic light: 73%
# car: 97%
# person: 50%
#
# FPS:15.4
#
#  cvWriteFrame
# Objects:
#
# traffic light: 43%
# car: 98%
# person: 82%
# person: 66%
#
# FPS:15.8
#
#  cvWriteFrame
# Objects:
#
# traffic light: 53%
# car: 95%
# person: 97%
# person: 52%
# person: 36%
#
# FPS:14.6
#
#  cvWriteFrame
# Objects:
#
# traffic light: 64%
# car: 94%
# person: 95%
# person: 86%
# person: 54%
# person: 50%
# person: 45%
# person: 29%
# person: 27%
#
# FPS:15.8
#
#  cvWriteFrame
# Objects:
#
# traffic light: 64%
# car: 91%
# person: 94%
# person: 84%
# person: 54%
# person: 35%
#
# FPS:18.3
#
#  cvWriteFrame
# Objects:
#
# car: 94%
# person: 55%
# person: 46%
#
# FPS:14.3
#
#  cvWriteFrame
# Objects:
#
# bear: 25%
# person: 87%
#
# FPS:16.6
#
#  cvWriteFrame
# Objects:
#
# person: 94%
# person: 89%
# person: 33%
#
# FPS:16.6
#
#  cvWriteFrame
# ...
#
# FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# car: 36%
# car: 33%
# person: 32%
#
# FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# truck: 33%
# car: 94%
# car: 77%
# car: 57%
# person: 65%
#
# FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# car: 77%
# car: 61%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.8
#
#  cvWriteFrame
# Objects:
#
# person: 45%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# truck: 39%
# car: 85%
# car: 48%
# person: 98%
#
# FPS:15.3
#
#  cvWriteFrame
# Objects:
#
# car: 95%
# car: 55%
# person: 92%
#
# FPS:16.1
#
#  cvWriteFrame
# Objects:
#
# car: 75%
# person: 45%
# person: 38%
#
# FPS:14.7
#
#  cvWriteFrame
# Objects:
#
# car: 55%
# person: 98%
#
# FPS:15.4
#
#  cvWriteFrame
# Objects:
#
# car: 49%
# person: 100%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# backpack: 26% handbag: 34%
# car: 85%
# person: 100%
#
# FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# car: 85%
# car: 57%
# person: 100%
#
# FPS:17.8
#
#  cvWriteFrame
# Objects:
#
# car: 33%
# person: 99%
#
# FPS:14.9
#
#  cvWriteFrame
# Objects:
#
# person: 71% horse: 43%
#
# FPS:14.8
#
#  cvWriteFrame
# Objects:
#
# truck: 34%
# car: 76%
# car: 43%
# car: 28%
# person: 98%
#
# FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# car: 52%
# car: 27%
# person: 79%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# car: 87%
# car: 38%
# person: 95%
#
# FPS:15.2
#
#  cvWriteFrame
# Objects:
#
# car: 63%
# car: 48%
# car: 32%
# person: 92%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# truck: 30%
# car: 77%
# person: 66%
#
# FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# truck: 55%
# car: 79%
# person: 60%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# car: 94%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# car: 92%
# car: 46%
# person: 73%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# car: 90%
# car: 78%
# person: 51%
#
# FPS:15.8
#
#  cvWriteFrame
# Objects:
#
# car: 89%
# car: 66%
#
# FPS:15.8
#
#  cvWriteFrame
# Objects:
#
# chair: 52%
# car: 51%
# person: 99%
#
# FPS:15.9
#
#  cvWriteFrame
# Objects:
#
# chair: 41%
# person: 99%
#
# FPS:16.1
#
#  cvWriteFrame
# Objects:
#
# chair: 63%
# car: 38%
# person: 100%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# chair: 43%
# person: 99%
#
# FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# chair: 51%
# person: 99%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# chair: 48%
# person: 99%
#
# FPS:14.9
#
#  cvWriteFrame
# Objects:
#
# chair: 53%
# car: 30%
# car: 29%
# person: 99%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# car: 38% chair: 37%
# person: 100%
#
# FPS:15.5
#
#  cvWriteFrame
# Objects:
#
# car: 38% truck: 31%
# person: 99%
#
# FPS:14.3
#
#  cvWriteFrame
# Objects:
#
# chair: 50%
# person: 100%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# person: 97%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# person: 97%
#
# FPS:16.1
#
#  cvWriteFrame
# Objects:
#
# person: 93%
#
# FPS:16.7
#
#  cvWriteFrame
# Objects:
#
# person: 98%
#
# FPS:15.4
#
#  cvWriteFrame
# Objects:
#
# car: 98%
# car: 41%
# person: 79%
# person: 74%
#
# FPS:15.8
#
#  cvWriteFrame
# Objects:
#
# car: 99%
# car: 45%
# person: 94%
# person: 84%
#
# FPS:15.8
#
#  cvWriteFrame
# Objects:
#
# cell phone: 27%
# car: 99%
# car: 37%
# person: 90%
# person: 89%
#
# FPS:14.3
#
#  cvWriteFrame
# Objects:
#
# cell phone: 73%
# car: 98%
# car: 36%
# person: 93%
# person: 82%
#
# FPS:15.5
#
#  cvWriteFrame
# Objects:
#
# car: 98%
# car: 35%
# car: 26%
# person: 77%
# person: 55%
#
# FPS:15.2
#
#  cvWriteFrame
# Objects:
#
# car: 98%
# car: 51%
# car: 35%
# person: 86%
# person: 82%
#
# FPS:15.1
#
#  cvWriteFrame
# Objects:
#
# cell phone: 28%
# car: 99%
# car: 42%
# person: 89%
# person: 78%
# person: 29%
#
# FPS:15.3
#
#  cvWriteFrame
# Objects:
#
# cell phone: 71%
# car: 99%
# car: 43%
# person: 92%
# person: 90%
#
# FPS:15.9
#
#  cvWriteFrame
# Objects:
#
# cell phone: 41%
# car: 99%
# car: 38%
# car: 27%
# person: 86%
# person: 85%
#
# FPS:16.6
#
#  cvWriteFrame
# Objects:
#
# cell phone: 32%
# car: 99%
# car: 39%
# car: 33%
# person: 82%
# person: 82%
#
# FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# cell phone: 34%
# cell phone: 28%
# car: 99%
# car: 36%
# person: 81%
# person: 67%
#
# FPS:15.2
#
#  cvWriteFrame
# Objects:
#
# car: 99%
# car: 32%
# person: 79%
# person: 79%
#
# FPS:16.1
#
#  cvWriteFrame
# Objects:
#
# car: 95%
# car: 93%
# person: 83%
#
# FPS:15.9
#
#  cvWriteFrame
# Objects:
#
# car: 94%
# car: 93%
# person: 83%
#
# FPS:14.7
#
#  cvWriteFrame
# Objects:
#
# truck: 27%
# car: 96%
# car: 94%
# person: 99%
# person: 39%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# truck: 34%
# car: 95%
# car: 91%
# person: 94%
# person: 25%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# truck: 43%
# car: 92%
# car: 88%
# person: 97%
# person: 32%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# car: 97%
# car: 85%
# person: 91%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# truck: 37%
# car: 74%
# car: 82%
# person: 96%
#
# FPS:14.7
#
#  cvWriteFrame
# Objects:
#
# cell phone: 40%
# truck: 41%
# car: 83%
# car: 95%
# person: 95%
#
# FPS:15.2
#
#  cvWriteFrame
# Objects:
#
# truck: 48%
# car: 91%
# car: 78%
# person: 98%
#
# FPS:15.1
#
#  cvWriteFrame
# Objects:
#
# car: 91%
# car: 59%
# person: 98%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# cell phone: 28%
# car: 94%
# car: 77%
# person: 99%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# cell phone: 56%
# car: 92%
# car: 55%
# person: 99%
#
# FPS:15.5
#
#  cvWriteFrame
# Objects:
#
# cell phone: 32%
# car: 92%
# person: 99%
# person: 32%
#
# FPS:17.4
#
#  cvWriteFrame
# Objects:
#
# car: 91%
# car: 66%
# person: 99%
# person: 44%
#
# FPS:14.2
#
#  cvWriteFrame
# Objects:
#
# cell phone: 50%
# car: 86%
# car: 52%
# car: 33%
# person: 99%
# person: 36%
#
# FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# cell phone: 80%
# car: 88%
# car: 58%
# person: 100%
#
# FPS:15.9
#
#  cvWriteFrame
# Objects:
#
# cell phone: 32%
# car: 89%
# car: 58%
# person: 98%
#
# FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# cell phone: 50%
# car: 86%
# car: 59%
# person: 96%
#
# FPS:14.9
#
#  cvWriteFrame
# Objects:
#
# cell phone: 32%
# car: 81%
# car: 39%
# person: 94%
#
# FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# car: 92%
# person: 88%
#
# FPS:15.8
#
#  cvWriteFrame
# Objects:
#
# car: 90%
# car: 56%
# person: 88%
#
# FPS:15.8
#
#  cvWriteFrame
# Objects:
#
# car: 95%
# car: 67%
# person: 94%
#
# FPS:16.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# car: 42%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# car: 97%
#
# FPS:15.1
#
#  cvWriteFrame
# Objects:
#
# car: 95%
#
# FPS:16.1
#
#  cvWriteFrame
# Objects:
#
# car: 99%
#
# FPS:15.2
#
#  cvWriteFrame
# Objects:
#
# parking meter: 37%
# car: 75%
#
# FPS:15.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# car: 99%
#
# FPS:15.3
#
#  cvWriteFrame
# Objects:
#
# car: 98%
# person: 64%
#
# FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# car: 98%
# person: 97%
#
# FPS:15.2
#
#  cvWriteFrame
# Objects:
#
# car: 97%
# person: 93%
#
# FPS:14.8
#
#  cvWriteFrame
# Objects:
#
# car: 98%
# person: 95%
#
# FPS:15.2
#
#  cvWriteFrame
# Objects:
#
# car: 96%
# person: 73%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# car: 74%
# person: 31%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# backpack: 30%
# car: 93%
# person: 93%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# car: 78%
# person: 98%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# car: 94%
# person: 98%
#
# FPS:15.1
#
#  cvWriteFrame
# Objects:
#
# car: 97%
# person: 93%
# person: 26%
#
# FPS:15.9
#
#  cvWriteFrame
# Objects:
#
# car: 89%
# person: 86%
# person: 45%
#
# FPS:16.1
#
#  cvWriteFrame
# Objects:
#
# backpack: 37%
# car: 66%
# person: 88%
#
# FPS:16.1
#
#  cvWriteFrame
# Objects:
#
# backpack: 46%
# car: 92%
# person: 68%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# car: 91%
# person: 96%
#
# FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# car: 98%
# person: 98%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# car: 97%
# person: 91%
#
# FPS:15.4
#
#  cvWriteFrame
# Objects:
#
# car: 95%
# person: 99%
#
# FPS:16.1
#
#  cvWriteFrame
# Objects:
#
# car: 92%
# person: 99%
#
# FPS:15.8
#
#  cvWriteFrame
# Objects:
#
# car: 95%
# person: 98%
#
# FPS:16.1
#
#  cvWriteFrame
# Objects:
#
# car: 88%
# person: 98%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# car: 89%
# person: 91%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# car: 89%
#
# FPS:15.9
#
#  cvWriteFrame
# Objects:
#
# car: 87%
#
# FPS:15.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.2
#
#  cvWriteFrame
# Objects:
#
# person: 35%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# person: 87%
#
# FPS:15.8
#
#  cvWriteFrame
# Objects:
#
# handbag: 38%
# person: 98%
#
# FPS:15.8
#
#  cvWriteFrame
# Objects:
#
# person: 84%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.3
#
#  cvWriteFrame
# Objects:
#
# person: 80%
#
# FPS:15.5
#
#  cvWriteFrame
# Objects:
#
# handbag: 48%
# person: 80%
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# person: 98%
#
# FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# person: 90%
#
# FPS:16.1
#
#  cvWriteFrame
# Objects:
#
# backpack: 53%
# person: 93%
#
# FPS:15.9
#
#  cvWriteFrame
# Objects:
#
# handbag: 41%
# person: 97%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 71%
#
# FPS:15.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.1
#
#  cvWriteFrame
# Objects:
#
# handbag: 27%
# backpack: 34%
# person: 94%
#
# FPS:15.1
#
#  cvWriteFrame
# Objects:
#
# backpack: 47%
# person: 100%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# backpack: 50%
# person: 96%
#
# FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# person: 96%
#
# FPS:15.9
#
#  cvWriteFrame
# Objects:
#
# backpack: 40%
# person: 83%
#
# FPS:15.1
#
#  cvWriteFrame
# Objects:
#
# person: 48%
#
# FPS:15.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# person: 63%
#
# FPS:15.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# person: 32%
#
# FPS:15.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.4
#
#  cvWriteFrame
# Objects:
#
# person: 89%
#
# FPS:16.7
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:15.2
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:15.2
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:15.2
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:14.9
#
#  cvWriteFrame
# Objects:
#
# person: 95%
#
# FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# person: 91%
# person: 30%
#
# FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# backpack: 40%
# person: 92%
# person: 29%
#
# FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# backpack: 25%
# person: 100%
#
# FPS:15.4
#
#  cvWriteFrame
# Objects:
#
# backpack: 49%
# person: 98%
#
# FPS:14.8
#
#  cvWriteFrame
# Objects:
#
# person: 73%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# person: 62%
#
# FPS:15.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.2
#
#  cvWriteFrame
# Objects:
#
# person: 79%
#
# FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# person: 70%
#
# FPS:14.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:13.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:14.7
#
#  cvWriteFrame
# Objects:
#
# person: 97%
# person: 47%
#
# FPS:15.5
#
#  cvWriteFrame
# Objects:
#
# person: 98%
# person: 81%
#
# FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:15.2
#
#  cvWriteFrame
# Objects:
#
# person: 96%
# person: 31%
#
# FPS:15.2
#
#  cvWriteFrame
# Objects:
#
# person: 97%
#
# FPS:15.1
#
#  cvWriteFrame
# Objects:
#
# person: 91%
#
# FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# person: 88%
#
# FPS:14.8
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:14.8
#
#  cvWriteFrame
# Objects:
#
# person: 99%
# person: 75%
#
# FPS:15.1
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# person: 92%
# person: 39%
#
# FPS:14.6
#
#  cvWriteFrame
# Objects:
#
# person: 96%
# person: 57%
#
# FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# backpack: 51%
# person: 68%
#
# FPS:15.9
#
#  cvWriteFrame
# Objects:
#
# person: 94%
#
# FPS:15.3
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:15.3
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# person: 98%
#
# FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# person: 97%
#
# FPS:15.1
#
#  cvWriteFrame
# Objects:
#
# backpack: 34%
# person: 92%
#
# FPS:15.8
#
#  cvWriteFrame
# Objects:
#
# backpack: 26%
# person: 100%
#
# FPS:15.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# person: 97%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# person: 93%
#
# FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# person: 93%
#
# FPS:14.6
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:15.9
#
#  cvWriteFrame
# Objects:
#
# person: 96%
#
# FPS:15.4
#
#  cvWriteFrame
# Objects:
#
# person: 99%
# person: 48%
#
# FPS:15.2
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:14.8
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:15.9
#
#  cvWriteFrame
# Objects:
#
# person: 97%
#
# FPS:15.2
#
#  cvWriteFrame
# Objects:
#
# person: 98%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:15.9
#
#  cvWriteFrame
# Objects:
#
# person: 95%
#
# FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# person: 98%
#
# FPS:15.1
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:15.5
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:15.2
#
#  cvWriteFrame
# Objects:
#
# person: 98%
#
# FPS:15.8
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:15.5
#
#  cvWriteFrame
# Objects:
#
# person: 93%
#
# FPS:15.1
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:15.1
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:15.9
#
#  cvWriteFrame
# Objects:
#
# person: 98%
#
# FPS:15.9
#
#  cvWriteFrame
# Objects:
#
# person: 98%
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:15.2
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:15.4
#
#  cvWriteFrame
# Objects:
#
# person: 96%
# person: 33%
#
# FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# person: 93%
#
# FPS:14.7
#
#  cvWriteFrame
# Objects:
#
# person: 96%
#
# FPS:14.9
#
#  cvWriteFrame
# Objects:
#
# person: 98%
#
# FPS:15.4
#
#  cvWriteFrame
# Objects:
#
# person: 97%
#
# FPS:15.4
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:15.5
#
#  cvWriteFrame
# Objects:
#
# person: 98%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# handbag: 46%
# person: 100%
#
# FPS:15.9
#
#  cvWriteFrame
# Objects:
#
# kite: 34%
# person: 99%
# person: 66%
#
# FPS:15.9
#
#  cvWriteFrame
# Objects:
#
# person: 98%
# person: 51%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:14.7
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:14.9
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:16.1
#
#  cvWriteFrame
# Objects:
#
# person: 100%
# person: 34%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# person: 96%
# person: 38%
#
# FPS:13.7
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# baseball bat: 32%
# person: 94%
# person: 37%
#
# FPS:15.9
#
#  cvWriteFrame
# Objects:
#
# person: 99%
# person: 60%
#
# FPS:14.8
#
#  cvWriteFrame
# Objects:
#
# person: 60%
# person: 25%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 100%
# person: 26%
#
# FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:16.1
#
#  cvWriteFrame
# Objects:
#
# person: 98%
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:15.4
#
#  cvWriteFrame
# Objects:
#
# person: 99%
#
# FPS:15.9
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:14.9
#
#  cvWriteFrame
# Objects:
#
# person: 100%
#
# FPS:15.3
#
#  cvWriteFrame
# Objects:
#
# person: 51%
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
# person: 60%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# person: 64%
#
# FPS:15.9
#
#  cvWriteFrame
# Objects:
#
# person: 43%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.9
#
#  cvWriteFrame
# Objects:
#
# refrigerator: 29%
#
# FPS:15.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.8
#
#  cvWriteFrame
# Objects:
#
# refrigerator: 32%
#
# FPS:15.8
#
#  cvWriteFrame
# Objects:
#
# refrigerator: 79%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# refrigerator: 78%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# refrigerator: 63%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# refrigerator: 48%
#
# FPS:15.2
#
#  cvWriteFrame
# Objects:
#
# refrigerator: 64%
#
# FPS:15.8
#
#  cvWriteFrame
# Objects:
#
# refrigerator: 54%
#
# FPS:14.6
#
#  cvWriteFrame
# Objects:
#
# refrigerator: 29%
#
# FPS:15.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# refrigerator: 60%
# refrigerator: 27%
#
# FPS:15.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:14.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# refrigerator: 53%
#
# FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# refrigerator: 32%
#
# FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# refrigerator: 36%
#
# FPS:16.0
# Stream closed.
#
#  cvWriteFrame
# input video stream closed.
#  closing... closed!output_video_writer closed.

# %%
#List files with details (Optional)
# %ls -al
# Out:
# total 564344
# drwxr-xr-x 15 root root      4096 Sep 22 17:21 ./
# drwxr-xr-x  1 root root      4096 Sep 22 17:15 ../
# drwxr-xr-x  4 root root      4096 Sep 22 17:15 3rdparty/
# -rw-r--r--  1 root root      5851 Sep 22 17:15 appveyor.yml
# drwxr-xr-x  2 root root      4096 Sep 22 17:17 backup/
# drwxr-xr-x  3 root root      4096 Sep 22 17:15 build/
# -rwxr-xr-x  1 root root      8265 Sep 22 17:15 build.ps1*
# -rwxr-xr-x  1 root root      2044 Sep 22 17:15 build.sh*
# drwxr-xr-x  3 root root      4096 Sep 22 17:15 cfg/
# drwxr-xr-x  2 root root      4096 Sep 22 17:15 .circleci/
# drwxr-xr-x  3 root root      4096 Sep 22 17:15 cmake/
# -rw-r--r--  1 root root     20019 Sep 22 17:15 CMakeLists.txt
# -rwxr-xr-x  1 root root   3665144 Sep 22 17:18 darknet*
# -rw-r--r--  1 root root      1363 Sep 22 17:15 DarknetConfig.cmake.in
# -rw-r--r--  1 root root     16517 Sep 22 17:15 darknet.py
# -rw-r--r--  1 root root      4010 Sep 22 17:15 darknet_video.py
# drwxr-xr-x  3 root root      4096 Sep 22 17:15 data/
# drwxr-xr-x  8 root root      4096 Sep 22 17:15 .git/
# -rw-r--r--  1 root root       581 Sep 22 17:15 .gitignore
# -rwxr-xr-x  1 root root       108 Sep 22 17:15 image_yolov2.sh*
# -rwxr-xr-x  1 root root       110 Sep 22 17:15 image_yolov3.sh*
# drwxr-xr-x  2 root root      4096 Sep 22 17:15 include/
# -rwxr-xr-x  1 root root       345 Sep 22 17:15 json_mjpeg_streams.sh*
# -rw-r--r--  1 root root       515 Sep 22 17:15 LICENSE
# -rw-r--r--  1 root root      4992 Sep 22 17:17 Makefile
# -rwxr-xr-x  1 root root       159 Sep 22 17:15 net_cam_v3.sh*
# drwxr-xr-x  2 root root      4096 Sep 22 17:18 obj/
# -rw-r--r--  1 root root     52713 Sep 22 17:15 README.md
# -rw-r--r--  1 root root 236152416 Sep 22 17:28 res.mp4
# drwxr-xr-x  2 root root      4096 Sep 22 17:17 results/
# drwxr-xr-x  4 root root      4096 Sep 22 17:15 scripts/
# drwxr-xr-x  2 root root      4096 Sep 22 17:15 src/
# -rw-r--r--  1 root root      9845 Sep 22 17:15 .travis.yml
# -rw-r--r--  1 root root  54371348 Sep 22 17:19 video.mp4
# -rwxr-xr-x  1 root root       108 Sep 22 17:15 video_v2.sh*
# -rwxr-xr-x  1 root root       108 Sep 22 17:15 video_yolov3.sh*
# -rw-r--r--  1 root root  35434956 May  6  2018 yolov3-tiny.weights
# -rw-r--r--  1 root root 248007048 Mar 25  2018 yolov3.weights

# %%
#Download result video directly
from google.colab import files
files.download('res.mp4')

# %%
#Mounting Drive  (Optional)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#Copying result video to drive (Optional)
# !cp /content/darknet/res.mp4 /content/drive/'My Drive'/

# %% [markdown]
# ## ----Tiny YOLO----

# %%
#Video detection on video.mp4 and store result in res.avi
# !./darknet detector demo cfg/coco.data cfg/yolov3-tiny.cfg yolov3-tiny.weights 'video.mp4' -out_filename 'res.mp4' -dont_show
